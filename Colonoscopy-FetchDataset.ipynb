# %%
# !mkdir Dataset

# %%
# Colitis with Mayo scores (TMC-UCM)
# https://ascpt.onlinelibrary.wiley.com/doi/pdf/10.1111/cts.13542
# dataset: https://pan.baidu.com/s/1Q09eWJAQgkZf4lrvE5hkKg?pwd=HUST

# !mkdir ./Dataset/TMC-UCM
# !gdown --folder -O ./Dataset/TMC-UCM 1uonpqcs9ynI5lhlnSPmu0D6D6ApSs0xg
# !unzip -d ./Dataset/TMC-UCM ./Dataset/TMC-UCM/augment.zip
# !unzip -d ./Dataset/TMC-UCM ./Dataset/TMC-UCM/images.zip
# !rm ./Dataset/TMC-UCM/*.zip

# %%
# HyperKvasir
# repo (osf): https://osf.io/mh9sj
# repo+doi (simulia): https://datasets.simula.no/hyper-kvasir

# !mkdir Dataset/HyperKvasir
# !wget -O ./Dataset/HyperKvasir/labeled-images.zip --no-check-certificate https://datasets.simula.no/downloads/hyper-kvasir/hyper-kvasir-labeled-images.zip
# !wget -O ./Dataset/HyperKvasir/segmented-images.zip --no-check-certificate https://datasets.simula.no/downloads/hyper-kvasir/hyper-kvasir-segmented-images.zip
# unused (25gb) !wget -O Dataset/HyperKvasir/unlabeled-images.zip --no-check-certificate https://datasets.simula.no/downloads/hyper-kvasir/hyper-kvasir-unlabeled-images.zip
# unused (29gb) !wget -O Dataset/HyperKvasir/videos.zip --no-check-certificate https://datasets.simula.no/downloads/hyper-kvasir/hyper-kvasir-videos.zip

# !unzip -d ./Dataset/HyperKvasir ./Dataset/HyperKvasir/labeled-images.zip
# !unzip -d ./Dataset/HyperKvasir ./Dataset/HyperKvasir/segmented-images.zip
# !rm ./Dataset/HyperKvasir/*.zip

# %%
# LIMUC
# https://zenodo.org/records/5827695?

# !mkdir Dataset/LIMUC
# !wget -O ./Dataset/LIMUC/patient_based_classified_images.zip --no-check-certificate https://zenodo.org/records/5827695/files/patient_based_classified_images.zip?download=1
# !wget -O ./Dataset/LIMUC/train_and_validation_sets.zip --no-check-certifi
athttps://zenodo.org/records/5827695/files/train_and_validation_sets.zip?download=1
# !wget -O ./Dataset/LIMUC/test_set.zip --no-check-certificate https://zenodo.org/records/5827695/files/test_set.zip?download=1

# !unzip -d ./Dataset/LIMUC ./Dataset/LIMUC/patient_based_classified_images.zip
# !unzip -d ./Dataset/LIMUC ./Dataset/LIMUC/train_and_validation_sets.zip
# !unzip -d ./Dataset/LIMUC ./Dataset/LIMUC/test_set.zip
